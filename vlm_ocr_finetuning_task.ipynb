# %%
# !pip install -q transformers datasets peft accelerate bitsandbytes torch Pillow tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning
# Out:
# /content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning

# %%
# !pip install -r requirements.txt

# %%
# !python prepare_dataset.py
# Out:
# Wrote 900 training records to: /content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning/data/train.json
# Wrote 50 test records to: /content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning/data/test.json
# Images saved under: /content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning/data/images

# %%
# !pip install -U transformers accelerate peft bitsandbytes

# %%
# !python finetune.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning/finetune.py", line 25, in <module>
#     from transformers import (
# ImportError: cannot import name 'AutoModelForVision2Seq' from 'transformers' (/usr/local/lib/python3.12/dist-packages/transformers/__init__.py)

# %%
# !pip install git+https://github.com/huggingface/transformers
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-2_dgqnus
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-2_dgqnus
#   Resolved https://github.com/huggingface/transformers to commit fefc3fa205aae3fb44127142e0771b0c8762ee46
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-5.3.0.dev0-py3-none-any.whl size=11299971 sha256=318c13d95be04e6e684dd6aeb7438d552cdb89fc6d12d0daabdf301b33465ba2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hjtvqus_/wheels/49/a7/50/c9fdabbf10e51bb1256adb0c1a587fedd7184f5bad28d47fe3
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.3.0
#     Uninstalling transformers-5.3.0:
#       Successfully uninstalled transformers-5.3.0
# ...

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning"
# Out:
# /content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning

# %%
# !pip uninstall -y transformers
# Out:
# Found existing installation: transformers 5.0.0
# Uninstalling transformers-5.0.0:
#   Successfully uninstalled transformers-5.0.0

# %%
# !pip install git+https://github.com/huggingface/transformers
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-0vohduq0
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-0vohduq0
#   Resolved https://github.com/huggingface/transformers to commit ec66c7fa70bf0194147382ec5e6d5b3ea90f9c3f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-5.3.0.dev0-py3-none-any.whl size=11299971 sha256=e5480b80e00cd899d558f403f035bc7c3c457e612dcca0809b9b411510e33273
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c0j3n_tu/wheels/49/a7/50/c9fdabbf10e51bb1256adb0c1a587fedd7184f5bad28d47fe3
# Successfully built transformers
# ...

# %%
# !pip install -U transformers accelerate peft bitsandbytes
import transformers
print(transformers.__version__)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 89.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 21.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 10.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.12.0
#     Uninstalling accelerate-1.12.0:
#       Successfully uninstalled accelerate-1.12.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.3.0.dev0
#     Uninstalling transformers-5.3.0.dev0:
#       Successfully uninstalled transformers-5.3.0.dev0
# ...
# 5.3.0

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning/finetune.py"
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning/finetune.py", line 25, in <module>
#     from transformers import (
# ImportError: cannot import name 'AutoModelForVision2Seq' from 'transformers' (/usr/local/lib/python3.12/dist-packages/transformers/__init__.py)

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning"
# Out:
# /content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning

# %%
# !python finetune.py
# Out:
# Loading model and processor: Qwen/Qwen2.5-VL-3B-Instruct
# ...
# preprocessor_config.json: 100% 350/350 [00:00<00:00, 1.68MB/s]
# chat_template.json: 1.05kB [00:00, 2.98MB/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# config.json: 1.37kB [00:00, 4.29MB/s]
# tokenizer_config.json: 5.70kB [00:00, 17.5MB/s]
# vocab.json: 2.78MB [00:00, 113MB/s]
# merges.txt: 1.67MB [00:00, 121MB/s]
# tokenizer.json: 7.03MB [00:00, 153MB/s]
# model.safetensors.index.json: 65.4kB [00:00, 136MB/s]
# ...
# Fetching 2 files: 100% 2/2 [07:00<00:00, 210.46s/it]
# Download complete: 100% 7.51G/7.51G [07:01<00:00, 17.8MB/s]
# Loading weights: 100% 824/824 [00:30<00:00, 26.97it/s]
# generation_config.json: 100% 216/216 [00:00<00:00, 1.34MB/s]
# ...

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning/finetune.py"
# Out:
# Loading model and processor: Qwen/Qwen2.5-VL-3B-Instruct
# preprocessor_config.json: 100% 350/350 [00:00<00:00, 1.48MB/s]
# chat_template.json: 1.05kB [00:00, 3.31MB/s]
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# ...
# config.json: 1.37kB [00:00, 6.38MB/s]
# tokenizer_config.json: 5.70kB [00:00, 17.1MB/s]
# vocab.json: 2.78MB [00:00, 87.2MB/s]
# merges.txt: 1.67MB [00:00, 101MB/s]
# tokenizer.json: 7.03MB [00:00, 152MB/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning/finetune.py", line 425, in <module>
#     main()
#   File "/content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning/finetune.py", line 357, in main
# ...

# %%
# !pip install -U bitsandbytes>=0.46.1

# %%
# !pip install -U transformers accelerate peft
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 88.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 38.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.12.0
#     Uninstalling accelerate-1.12.0:
#       Successfully uninstalled accelerate-1.12.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# ...

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning"
# Out:
# /content/drive/MyDrive/Colab Notebooks/vlm_ocr_finetuning

# %%
# !python finetune.py
# Out:
# Loading model and processor: Qwen/Qwen2.5-VL-3B-Instruct
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# ...
# model.safetensors.index.json: 65.4kB [00:00, 87.9MB/s]
# ...
# Fetching 2 files: 100% 2/2 [02:34<00:00, 77.14s/it]
# Download complete: 100% 7.51G/7.51G [02:34<00:00, 48.6MB/s]
# Loading weights: 100% 824/824 [00:29<00:00, 28.35it/s]
# generation_config.json: 100% 216/216 [00:00<00:00, 1.12MB/s]
# Model loaded successfully with 4-bit quantization
# Setting up LoRA adapters...
# trainable params: 37,152,768 || all params: 3,791,775,744 || trainable%: 0.9798
# LoRA adapters configured successfully
# Loading dataset from: data/train.json
# Loaded 900 examples
# Preprocessing dataset...
# ...

# %%
# !pip install -U transformers accelerate peft bitsandbytes

# %%
# !python inference.py
# Out:
# ...
# The image processor of type `Qwen2VLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# ...
# Fetching 2 files: 100% 2/2 [00:00<00:00, 334.18it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading weights: 100% 824/824 [00:29<00:00, 27.85it/s]
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
#
# ...
# SAMPLE: 1
# ...
#
# 📄 Ground Truth
#
# 1
# EGG TART
# 13,000
# 2
# CHOCO CUS ARD PASTRY
# 24,000
# 1
# REDBEAN BREAD
# 9,000
# TOTAL 46,000
# CASH 50,000
# CHANGE 4,000
#
# 🔵 Base Model
#
#
#
# 🟢 Fine-tuned Model
#
#
# ...
#
# ...
# SAMPLE: 2
# ...
#
# 📄 Ground Truth
#
# 1X
# S-Bubble Milk Tea
# @20,000
# 20,000
# 100%
# 1X
# S-Caramel Milk Tea
# @20,000
# 20,000
# 100%
# Total: 40,000
# Cash: 40,000
# ...

# %%
# !pip install -U transformers accelerate peft bitsandbytes jiwer nltk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 124.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.1
#     Uninstalling nltk-3.9.1:
#       Successfully uninstalled nltk-3.9.1
# ...
